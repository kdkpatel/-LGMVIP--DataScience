# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='Latin1')
df.head()
# Out:
# C:\Users\Kadambari\AppData\Local\Temp\ipykernel_14396\2337785049.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='Latin1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns.to_list()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
terror = df[['iyear','country_txt','region_txt','city','success','attacktype1_txt','targtype1_txt','targsubtype1_txt','target1','natlty1_txt','gname','motive','nkill','property']]

# %%
terror.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   country_txt       181691 non-null  object
#  2   region_txt        181691 non-null  object
#  3   city              181257 non-null  object
#  4   success           181691 non-null  int64
#  5   attacktype1_txt   181691 non-null  object
#  6   targtype1_txt     181691 non-null  object
#  7   targsubtype1_txt  171318 non-null  object
#  8   target1           181055 non-null  object
#  9   natlty1_txt       180132 non-null  object
#  10  gname             181691 non-null  object
#  11  motive            50561 non-null   object
#  12  nkill             171378 non-null  float64
#  13  property          181691 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 19.4+ MB

# %%
# The unique() function returns all the unique values of the column in the form of an array
# The nunique() function returns the number of all unique values

# %%
terror.country_txt.nunique()
# Out:
# 205

# %%
terror.region_txt.value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: region_txt, dtype: int64

# %%
plt.figure(figsize=(22,10))
plt.bar(x = terror.region_txt.value_counts().index,height= terror.region_txt.value_counts().values)
plt.title('Terrorist activities regionwise from 1970-2017')
plt.xlabel('Countries')
plt.ylabel('No.of terrorists activities')
# Out:
# Text(0, 0.5, 'No.of terrorists activities')

# %%
terror.country_txt.value_counts().tail(50)
# Out:
# Martinique                        12
# Serbia                            12
# Serbia-Montenegro                 11
# East Timor                        10
# Botswana                          10
# Eritrea                           10
# Czechoslovakia                    10
# Guinea-Bissau                      9
# Gabon                              8
# Lithuania                          8
# Benin                              8
# Belize                             8
# Qatar                              7
# Singapore                          7
# French Guiana                      7
# Romania                            6
# Bhutan                             6
# North Yemen                        6
# Slovenia                           6
# Brunei                             6
# Grenada                            5
# Bahamas                            5
# Montenegro                         5
# Western Sahara                     5
# Comoros                            5
# ...

# %%
terror[terror.country_txt=='Andora']
# Out:
# Empty DataFrame
# Columns: [iyear, country_txt, region_txt, city, success, attacktype1_txt, targtype1_txt, targsubtype1_txt, target1, natlty1_txt, gname, motive, nkill, property]
# Index: []

# %%
terror.country_txt.value_counts().head(10)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: country_txt, dtype: int64

# %%
plt.figure(figsize=(22,10))
plt.bar(x = terror.country_txt.value_counts().head(10).index,height= terror.country_txt.value_counts().head(10).values)
plt.title('Terrorist activities regionwise from 1970-2017')
plt.xlabel('Countries')
plt.ylabel('No.of terrorists activities')
# Out:
# Text(0, 0.5, 'No.of terrorists activities')

# %%
terror.gname.value_counts().head(11)[1:]
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Name: gname, dtype: int64

# %%
sns.barplot(x = terror.gname.value_counts().head(11)[1:].values, y= terror.gname.value_counts().head(11)[1:].index)
plt.title('Attacks by terrorists Organizations')
plt.xlabel('Count')
plt.ylabel('Terrorists Organization')
# Out:
# Text(0, 0.5, 'Terrorists Organization')

# %%
terror.attacktype1_txt.value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
sns.barplot(x = terror.attacktype1_txt.value_counts().values, y= terror.attacktype1_txt.value_counts().index)
plt.title('Type of attack')
plt.xlabel('Count')
plt.ylabel('Strike mode')
# Out:
# Text(0, 0.5, 'Strike mode')

# %%
terror.targtype1_txt.value_counts()
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: targtype1_txt, dtype: int64

# %%
plt.figure(figsize=(10,6))

# %%
sns.barplot(x = terror.targtype1_txt.value_counts().values, y= terror.targtype1_txt.value_counts().index)
plt.title('Type of Target')
plt.xlabel('Count')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %%
# ANALYSIS ON INDIA

# %%
India = terror[terror.country_txt=='India']

# %%
India.head(10)
# Out:
#       iyear country_txt  region_txt        city  success  \
# 1186   1972       India  South Asia   New Delhi        1
# 2764   1975       India  South Asia  Samastipur        1
# 3857   1976       India  South Asia   New Delhi        1
# 5327   1977       India  South Asia      Bombay        1
# 7337   1979       India  South Asia     Unknown        1
# 7342   1979       India  South Asia      Imphal        1
# 8174   1979       India  South Asia     Unknown        1
# 8685   1979       India  South Asia     Unknown        1
# 8831   1979       India  South Asia     Unknown        1
# 8836   1979       India  South Asia      Aizawl        1
#
#                      attacktype1_txt         targtype1_txt  \
# 1186                       Hijacking   Airports & Aircraft
# 2764               Bombing/Explosion  Government (General)
# 3857               Bombing/Explosion   Airports & Aircraft
# 5327                       Hijacking   Airports & Aircraft
# ...

# %%
India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11960 entries, 1186 to 181689
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   iyear             11960 non-null  int64
#  1   country_txt       11960 non-null  object
#  2   region_txt        11960 non-null  object
#  3   city              11960 non-null  object
#  4   success           11960 non-null  int64
#  5   attacktype1_txt   11960 non-null  object
#  6   targtype1_txt     11960 non-null  object
#  7   targsubtype1_txt  11113 non-null  object
#  8   target1           11918 non-null  object
#  9   natlty1_txt       11934 non-null  object
#  10  gname             11960 non-null  object
#  11  motive            5685 non-null   object
#  12  nkill             11740 non-null  float64
#  13  property          11960 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.4+ MB

# %%
India.success.value_counts()
# Out:
# 1    10280
# 0     1680
# Name: success, dtype: int64

# %%
India.iyear.value_counts().index.sort_values()
# Out:
# Int64Index([1972, 1975, 1976, 1977, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
#             1986, 1987, 1988, 1989, 1990, 1991, 1992, 1994, 1995, 1996, 1997,
#             1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#             2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64')

# %%
plt.figure(figsize=(20,6))
sns.barplot(y = India.iyear.value_counts().values,x = India.iyear.value_counts().index)
plt.title('Terror attack in India')
plt.xlabel('Year')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
India.city.value_counts().head(11)
# Out:
# Srinagar            658
# Unknown             624
# Imphal              426
# New Delhi           157
# Amritsar            138
# Sopore              102
# Ludhiana             77
# Guwahati             77
# Anantnag             76
# Jammu                57
# Latehar district     55
# Name: city, dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.barplot(y = India.city.value_counts().head(11).values,x = India.city.value_counts().head(11).index)
plt.title('Cities which were attacked')
plt.xlabel('Count')
plt.ylabel('City')
# Out:
# Text(0, 0.5, 'City')

# %%
India[India.iyear>=2008].city.value_counts().head(10)
# Out:
# Imphal                     388
# Srinagar                   108
# Unknown                    103
# Sopore                      68
# Latehar district            54
# Bijapur district            50
# Sukma district              49
# West Midnapore district     41
# Malkangiri district         40
# Dantewada district          35
# Name: city, dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.barplot(y = India[India.iyear>=2008].city.value_counts().head(10).values,x = India[India.iyear>=2008].city.value_counts().head(10).index)
plt.title('Cities which were attacked after 2008')
plt.xlabel('Count')
plt.ylabel('City')
# Out:
# Text(0, 0.5, 'City')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = terror.attacktype1_txt.value_counts().values,y = terror.attacktype1_txt.value_counts().index)
plt.title('Type of attack')
plt.xlabel('Count')
plt.ylabel('Type of strike')
# Out:
# Text(0, 0.5, 'Type of strike')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = terror.targtype1_txt.value_counts().values,y = terror.targtype1_txt.value_counts().index)
plt.title('Type of target')
plt.xlabel('Count')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = terror.targsubtype1_txt.value_counts().head(10).values,y = terror.targsubtype1_txt.value_counts().head(10).index)
plt.title('Type of subtarget')
plt.xlabel('Count')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %%
India.gname.value_counts().head(30)[1:]
# Out:
# Communist Party of India - Maoist (CPI-Maoist)                  1877
# Maoists                                                         1396
# Sikh Extremists                                                  710
# United Liberation Front of Assam (ULFA)                          357
# Hizbul Mujahideen (HM)                                           199
# Lashkar-e-Taiba (LeT)                                            187
# National Democratic Front of Bodoland (NDFB)                     174
# Garo National Liberation Army                                    166
# Muslim Separatists                                               118
# People's War Group (PWG)                                          97
# National Socialist Council of Nagaland-Isak-Muivah (NSCN-IM)      89
# People's Liberation Army (India)                                  88
# Bodo Militants                                                    87
# Muslim Militants                                                  87
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = India.gname.value_counts().head(30)[1:].values,y = India.gname.value_counts().head(30)[1:].index)
plt.title('Terror organiztion who attacked in India')
plt.xlabel('Count')
plt.ylabel('Terror Organization')
# Out:
# Text(0, 0.5, 'Terror Organization')

# %%
plt.figure(figsize=(20,6))
sns.barplot(x = India[India.iyear>2007].gname.value_counts().head(5)[1:].values,y = India[India.iyear>2007].gname.value_counts().head(5)[1:].index)
plt.title('Cities which were attacked after 2007')
plt.xlabel('Count')
plt.ylabel('Terror Organization')
# Out:
# Text(0, 0.5, 'Terror Organization')

# %%
# ANALYSIS ON PAKISTAN

# %%
Pakistan = terror[terror.country_txt=='Pakistan']

# %%
Pakistan.head(10)
# Out:
#       iyear country_txt  region_txt        city  success  \
# 585    1970    Pakistan  South Asia     Karachi        1
# 2217   1974    Pakistan  South Asia     Karachi        1
# 2705   1974    Pakistan  South Asia    Peshawar        1
# 2744   1975    Pakistan  South Asia  Rawalpindi        1
# 2795   1975    Pakistan  South Asia    Peshawar        1
# 4180   1976    Pakistan  South Asia  Rawalpindi        1
# 4181   1976    Pakistan  South Asia     Karachi        1
# 4214   1976    Pakistan  South Asia   Islamabad        1
# 6583   1978    Pakistan  South Asia     Karachi        1
# 6592   1978    Pakistan  South Asia   Islamabad        1
#
#                      attacktype1_txt                 targtype1_txt  \
# 585                    Assassination       Government (Diplomatic)
# 2217               Bombing/Explosion                      Maritime
# 2705               Bombing/Explosion       Government (Diplomatic)
# ...

# %%
Pakistan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14368 entries, 585 to 181650
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   iyear             14368 non-null  int64
#  1   country_txt       14368 non-null  object
#  2   region_txt        14368 non-null  object
#  3   city              14357 non-null  object
#  4   success           14368 non-null  int64
#  5   attacktype1_txt   14368 non-null  object
#  6   targtype1_txt     14368 non-null  object
#  7   targsubtype1_txt  13309 non-null  object
#  8   target1           14348 non-null  object
#  9   natlty1_txt       14305 non-null  object
#  10  gname             14368 non-null  object
#  11  motive            5060 non-null   object
#  12  nkill             14119 non-null  float64
#  13  property          14368 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.6+ MB

# %%
Pakistan.success.value_counts()
# Out:
# 1    12600
# 0     1768
# Name: success, dtype: int64

# %%
Pakistan.iyear.value_counts().index.sort_values()
# Out:
# Int64Index([1970, 1974, 1975, 1976, 1978, 1979, 1980, 1981, 1982, 1983, 1984,
#             1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1994, 1995, 1996,
#             1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#             2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],
#            dtype='int64')

# %%
plt.figure(figsize=(20,6))
sns.barplot(y = Pakistan.iyear.value_counts().values,x = Pakistan.iyear.value_counts().index)
plt.title('Terror attack in Pakistan')
plt.xlabel('Year')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
India.city.value_counts().head(11)
# Out:
# Srinagar            658
# Unknown             624
# Imphal              426
# New Delhi           157
# Amritsar            138
# Sopore              102
# Ludhiana             77
# Guwahati             77
# Anantnag             76
# Jammu                57
# Latehar district     55
# Name: city, dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.barplot(y = Pakistan.city.value_counts().head(11).values,x = Pakistan.city.value_counts().head(11).index)
plt.title('Cities which were attacked')
plt.xlabel('Count')
plt.ylabel('City')
# Out:
# Text(0, 0.5, 'City')

# %%
Pakistan[Pakistan.iyear>=2008].city.value_counts().head(10)
# Out:
# Karachi             1437
# Quetta               726
# Peshawar             694
# Jamrud               160
# Bara                 155
# Landi Kotal          139
# Mohmand district     136
# Dera Bugti           133
# Bannu                127
# Hangu                124
# Name: city, dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.barplot(y = Pakistan[Pakistan.iyear>=2008].city.value_counts().head(10).values,x = Pakistan[Pakistan.iyear>=2008].city.value_counts().head(10).index)
plt.title('Cities which were attacked after 2008')
plt.xlabel('Count')
plt.ylabel('City')
# Out:
# Text(0, 0.5, 'City')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = terror.attacktype1_txt.value_counts().values,y = terror.attacktype1_txt.value_counts().index)
plt.title('Type of attack')
plt.xlabel('Count')
plt.ylabel('Type of strike')
# Out:
# Text(0, 0.5, 'Type of strike')

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = terror.targtype1_txt.value_counts().values,y = terror.targtype1_txt.value_counts().index)
plt.title('Type of target')
plt.xlabel('Count')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %%
Pakistan.gname.value_counts().head(30)[1:]
# Out:
# Tehrik-i-Taliban Pakistan (TTP)               1335
# Baloch Republican Army (BRA)                   312
# Baloch Liberation Front (BLF)                  185
# Baloch Liberation Army (BLA)                   181
# Muttahida Qami Movement (MQM)                  174
# Lashkar-e-Jhangvi                              135
# Lashkar-e-Islam (Pakistan)                     124
# Khorasan Chapter of the Islamic State           96
# United Baloch Army (UBA)                        89
# Sindhu Desh Liberation Army (SDLA)              57
# Taliban                                         54
# Gunmen                                          40
# Taliban (Pakistan)                              38
# Lashkar-e-Balochistan                           32
# Militants                                       32
# Baloch Nationalists                             31
# Balochistan Liberation United Front (BLUF)      28
# Jaish-e-Islam                                   24
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = Pakistan.gname.value_counts().head(30)[1:].values,y = Pakistan.gname.value_counts().head(30)[1:].index)
plt.title('Terror organiztion who attacked in Pakistan')
plt.xlabel('Count')
plt.ylabel('Terror Organization')
# Out:
# Text(0, 0.5, 'Terror Organization')

# %%
plt.figure(figsize=(20,6))
sns.barplot(x = Pakistan[Pakistan.iyear>2007].gname.value_counts().head(5)[1:].values,y = Pakistan[Pakistan.iyear>2007].gname.value_counts().head(5)[1:].index)
plt.title('Cities which were attacked after 2007')
plt.xlabel('Count')
plt.ylabel('Terror Organization')
# Out:
# Text(0, 0.5, 'Terror Organization')
